# %% [markdown]
# Using the data from Question 4, write code to analyze the data and answer the following questions Note -
# 1. Draw plots to demonstrate the analysis for the following questions for better visualizations
# 2. Write code comments wherever required for code understanding
#
# Insights to be drawn -
# ● Get all the Earth meteorites that fell before the year 2000
# ● Get all the earth meteorites co-ordinates who fell before the year 1970
# ● Assuming that the mass of the earth meteorites was in kg, get all those whose mass was more
# than 10000kg

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pandas as pd

# %%
df=pd.read_csv("nasa_data.csv")

# %%
df
# Out:
#           name     id nametype               recclass      mass  fall    year
# 0       Aachen      1    Valid                     L5      21.0  Fell  1880.0  \
# 1       Aarhus      2    Valid                     H6     720.0  Fell  1951.0
# 2         Abee      6    Valid                    EH4  107000.0  Fell  1952.0
# 3     Acapulco     10    Valid            Acapulcoite    1914.0  Fell  1976.0
# 4      Achiras    370    Valid                     L6     780.0  Fell  1902.0
# ..         ...    ...      ...                    ...       ...   ...     ...
# 995   Tirupati  24009    Valid                     H6     230.0  Fell  1934.0
# 996    Tissint  54823    Valid  Martian (shergottite)    7000.0  Fell  2011.0
# 997      Tjabe  24011    Valid                     H6   20000.0  Fell  1869.0
# 998   Tjerebon  24012    Valid                     L5   16500.0  Fell  1922.0
# 999  Tomakovka  24019    Valid                    LL6     600.0  Fell  1905.0
#
# ...

# %%
#  Get all the Earth meteorites that fell before the year 2000
fell_before=df[df["year"] < 2000]
fell_before=fell_before[["name","year"]]
print(len(fell_before))
fell_before
# Out:
# 929
#           name    year
# 0       Aachen  1880.0
# 1       Aarhus  1951.0
# 2         Abee  1952.0
# 3     Acapulco  1976.0
# 4      Achiras  1902.0
# ..         ...     ...
# 994   Timochin  1807.0
# 995   Tirupati  1934.0
# 997      Tjabe  1869.0
# 998   Tjerebon  1922.0
# 999  Tomakovka  1905.0
#
# [929 rows x 2 columns]

# %%
df1=df[df["year"]< 2000]
df1.sort_values(by="year", ascending=True)
# Out:
#                  name     id nametype    recclass      mass  fall    year
# 704            Nogata  16988    Valid          L6     472.0  Fell   861.0  \
# 679             Narni  16914    Valid  Stone-uncl       NaN  Fell   921.0
# 278           Elbogen   7823    Valid   Iron, IID  107000.0  Fell  1400.0
# 856  Rivolta de Bassi  22614    Valid  Stone-uncl     103.3  Fell  1491.0
# 283         Ensisheim  10039    Valid         LL6  127000.0  Fell  1492.0
# ..                ...    ...      ...         ...       ...   ...     ...
# 491              Kobe  12336    Valid         CK4     136.0  Fell  1999.0
# 246          Djoumine   7657    Valid        H5-6   10000.0  Fell  1999.0
# 535    Leighlinbridge  12759    Valid          L6     271.4  Fell  1999.0
# 459           Katagum  35465    Valid          L6    1500.0  Fell  1999.0
# 115           Bilanga   5045    Valid   Diogenite   25000.0  Fell  1999.0
#
#        reclat    reclong geolocation.type geolocation.coordinates
# ...

# %%
plt.figure(figsize=(10, 6))
plt.hist(fell_before["year"],bins=50)
plt.xlabel('Year')
plt.ylabel('Count of meteorites')
plt.title('Meteorites that fell before the year 2000')
plt.show()

# %%
# Get all the earth meteorites co-ordinates who fell before the year 1970
coordinates_before_1970 = df.loc[(df['year'] < 1970),['reclat','reclong' , 'year']]
coordinates_before_1970
# Out:
#        reclat    reclong    year
# 0    50.77500    6.08333  1880.0
# 1    56.18333   10.23333  1951.0
# 2    54.21667 -113.00000  1952.0
# 4   -33.16667  -64.95000  1902.0
# 5    32.10000   71.80000  1919.0
# ..        ...        ...     ...
# 994  54.50000   35.20000  1807.0
# 995  13.63333   79.41667  1934.0
# 997  -7.08333  111.53333  1869.0
# 998  -6.66667  106.58333  1922.0
# 999  47.85000   34.76667  1905.0
#
# [780 rows x 3 columns]

# %%
plt.figure(figsize=(10, 6))
plt.scatter(coordinates_before_1970['reclong'], coordinates_before_1970['reclat'])
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Coordinates of Earth Meteorites fell Before 1970')
plt.show()

# %%
# Assuming that the mass of the earth meteorites was in kg, get all those whose mass was more than 10000kg
mass=df.loc[(df["mass"]>10000),['name','mass']].sort_values(by="mass", ascending=False)
mass
# Out:
#               name        mass
# 920   Sikhote-Alin  23000000.0
# 419          Jilin   4000000.0
# 29         Allende   2000000.0
# 707  Norton County   1100000.0
# 506  Kunya-Urgench   1100000.0
# ..             ...         ...
# 960   Stretchleigh     10400.0
# 66          Bahjoi     10322.0
# 686          Nerft     10250.0
# 828  Raghunathpura     10200.0
# 300          Fermo     10200.0
#
# [243 rows x 2 columns]

# %%
plt.figure(figsize=(10, 6))
bins = [0, 10000, 100000, 1000000]
plt.hist(df['mass'], bins=bins)
plt.xlabel('Mass bins')
plt.ylabel('Count of meteorites')
plt.title('Meteorites which has more mass than 10000kg')
plt.show()
